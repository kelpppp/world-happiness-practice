# %% [markdown]
# # World Happiness Report — Exploratory Practice
#
# **Dataset:** World Happiness Report (source: [Kaggle link here])
#
# **Goal:** Practice pandas fundamentals (inspecting, filtering, sorting, grouping) by exploring what factors relate to happiness scores across countries.
#
# **Date started:**
# **Author:** Annie

# %% [markdown]
# ## 1. Imports & Setup

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2. Loading the Data

# %%
# df = pd.read_csv('data/your_file_name.csv')

# %% [markdown]
# ## 3. Inspecting the Data
#
# Before doing anything else, get a feel for what you're working with: shape, columns, dtypes, missing values.

# %% [markdown]
# **Q: What are the shape, column names, and dtypes of the dataframe?**

# %% [markdown]
# *Takeaway:*

# %% [markdown]
# **Q: Are there any missing values, and in which columns?**

# %% [markdown]
# *Takeaway:*

# %% [markdown]
# **Q: What's the mean, min, and max of the happiness score column?**

# %% [markdown]
# *Takeaway:*

# %% [markdown]
# ## 4. Cleaning
#
# Handle anything you found above — missing values, odd column names, wrong dtypes, etc. Skip this section if the data's already clean enough.

# %% [markdown]
# ## 5. Analysis: Tier 1 — Sorting & Filtering

# %% [markdown]
# **Q: Which 10 countries have the highest happiness score?**

# %% [markdown]
# *Takeaway:*

# %% [markdown]
# **Q: Which 10 countries have the lowest happiness score?**

# %% [markdown]
# *Takeaway:*

# %% [markdown]
# **Q: (Optional) Among countries with GDP-per-capita above the median, which 10 have the lowest happiness score?**

# %% [markdown]
# *Takeaway:*

# %% [markdown]
# ## 6. Analysis: Tier 2 — Grouping

# %% [markdown]
# **Q: How many countries are in each region?**

# %% [markdown]
# *Takeaway:*

# %% [markdown]
# **Q: What's the average happiness score per region? Which region is happiest on average?**

# %% [markdown]
# *Takeaway:*

# %% [markdown]
# **Q: Within each region, what's the average GDP-per-capita? Does the highest-GDP region also have the highest happiness score?**

# %% [markdown]
# *Takeaway:*

# %% [markdown]
# ## 7. Analysis: Tier 3 — Merging (if using multiple years)

# %% [markdown]
# **Q: Merge two years of data on country name. Which countries had the biggest increase / decrease in happiness score year-over-year?**

# %% [markdown]
# *Takeaway:*

# %% [markdown]
# ## 8. Analysis: Your Own Questions
#
# Write 1-3 questions you're genuinely curious about, then answer them below.

# %% [markdown]
# **Q: **

# %% [markdown]
# *Takeaway:*

# %% [markdown]
# ## 9. Summary
#
# - What did you find?
# - What surprised you?
# - What would you explore next?
